# %%
import numpy as np
from scipy.stats import norm
from scipy import optimize
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from math import *
import pandas as pd
from scipy.optimize import curve_fit,leastsq
import statistics
from scipy import interpolate
import matplotlib as mpl

# %% [markdown]
# <h1>Define<h1>

# %%
def gauss(x, H, A, x0, sigma):
    return H + A * np.exp(-(x - x0) ** 2 / (2 * sigma ** 2))
def gauss_fit(x, y):
    mean = sum(x * y) / sum(y)
    sigma = np.sqrt(sum(y * (x - mean) ** 2) / sum(y))
    popt, pcov = curve_fit(gauss, x, y, p0=[min(y), max(y), mean, sigma])
    return np.abs(popt)

# %%
def gauss_fit_pcov(x, y):
    mean = sum(x * y) / sum(y)
    sigma = np.sqrt(sum(y * (x - mean) ** 2) / sum(y))
    popt, pcov = curve_fit(gauss, x, y, p0=[min(y), max(y), mean, sigma])
    return pcov

# %%
def MOT_sim(initial_size, temp, order, sigma_raw):
    mu = 0
    sigma_velocity = np.sqrt((k/rubidium_mass)*(temp))
    velocity=np.random.normal(mu,sigma_velocity,10000)
    x_not=np.random.normal(0,(initial_size),10000)
    time = np.arange(0,order+2,1)*1e-3
    data_column = [velocity]+[x_not+(velocity*time[i]) for i in range(order+1)]

    sigma_fit = []
    for j in range(2,order+2):
        mu, std = norm.fit(data_column[j])
        sigma_fit.append(std)

    return np.array(sigma_fit)

# %%
def MOT_gen (initial_size,Resolution_data,temp,sigma_raw):
    mu = 0
    sigma_velocity = np.sqrt((k/rubidium_mass)*(temp))
    sigma_fit = []
    velocity=np.random.normal(mu,sigma_velocity,10000)
    x_not=np.random.normal(0,(initial_size),10000)
    point_of_time = sigma_raw.shape[0]
    times = np.arange(0,point_of_time,1)*1e-3
    time = np.linspace(0,point_of_time,Resolution_data)*1e-3
    data_column = [x_not+(velocity*time[i]) for i in range(Resolution_data)]
    for j in range(0,Resolution_data):
        mu, std = norm.fit(data_column[j])
        sigma_fit.append(std)
    return np.array(sigma_fit),times,time

# %%
def Multi_MOT_gen(initial_size,Resolution_data,temp,sigma_raw):
    mu = 0
    n = sigma_raw.shape[0]
    x_not = np.random.normal(mu,initial_size,10000)
    times = np.arange(0,n,1)*1e-3
    time = np.linspace(0,n,Resolution_data)*1e-3
    std_fit = []
    for i in range(temp.shape[0]):
        sigma_velocity = np.sqrt((k/rubidium_mass)*(temp[i]))
        std_l = []
        velocity=np.random.normal(mu,sigma_velocity,10000)
        data_column = [x_not+(velocity*time[i]) for i in range(Resolution_data)]
        for j in range(0,Resolution_data):
            mu, std = norm.fit(data_column[j])
            std_l.append(std)
        std_fit.append(std_l)
    return np.array(std_fit),times,time

# %%
# scale_factor = 0.0005853782630731235/21.156368179088226
sigma_err = np.array([0.54697102 ,0.50053797 ,0.64864047 ,0.83312344 ,1.44395329 ,3.30220595 ])#,8.47620527 ,7.22363419 ,165.29643617 ,49.07438558]
sigma_exp = np.array([0.00058538, 0.00057708, 0.00062619, 0.0007367 , 0.00081651, 0.00103968])
rubidium_mass=1.409993e-25
k=1.380649e-23
mu = 0
ini_MOT_size = 0.0005853782630731235

# %%
sigma_err_m = sigma_err *

# %% [markdown]
# <h1>Cloud atom simulation<h1>

# %%
temp_array_test = np.array([5e-6,20e-6,50e-6,100e-6,150e-6,250e-6,400e-6,])
MOT_sim_5t = Multi_MOT_gen(ini_MOT_size,100,temp_array_test,sigma_exp)[0]
def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)
c1='blue' #blue
c2='red' #green
n=7

for i in range(7):
    plt.plot(np.linspace(0,7,100),MOT_sim_5t[i]*1000000,color=colorFader(c1,c2,i/n),label = str(np.round(temp_array_test[i]*1000000,2))+' $\mu$K')
    
# plt.errorbar(np.arange(1,7) ,sigma_exp*1000000, sigma_err_m*1000000,color = 'black',fmt ='o',label = 'Experiment data',capsize=3, elinewidth=1, mfc = 'orange')
plt.ylim(550,1200)
plt.xlim(0,7)
plt.ylabel('Atomic radius ($\mu$m)')
plt.xlabel('$\Delta t$ (ms)')
plt.grid()
# plt.title('Ballistic expansion from 5 $\mu$K to 400 $\mu$K')
plt.legend(fontsize = "small")
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\Ballistic expansion from 5 to 400 micro_kelvin.png')

# %%
def MOT_sim_his(initial_size, temp, order, sigma_raw):
    mu = 0
    sigma_velocity = np.sqrt((k/rubidium_mass)*(temp))
    velocity=np.random.normal(mu,sigma_velocity,10000)
    x_not=np.random.normal(0,initial_size,10000)
    
    index_column = ['V'] + ['X'+str(k) for k in range(order+1)]
    time = np.arange(0,order+2,1)*1e-3
    data_column = [velocity]+[x_not+(velocity*time[i]) for i in range(order+1)]

    position = pd.DataFrame()
    position = pd.DataFrame({index_column[0]:data_column[0]})
    for j in range(1,order+2):
        position = position.join(pd.DataFrame({index_column[j]:data_column[j]}))

    return position, index_column

# %%
color=['brown','red','orange','gold','lightgreen','darkcyan','blue','darkviolet','black']
position_df ,index_column= MOT_sim_his(ini_MOT_size, 250e-6, 7, sigma_exp)
position_df
# Out:
#              V        X0        X1        X2        X3        X4        X5  \
# 0     0.112238  0.001066  0.001178  0.001290  0.001402  0.001514  0.001627
# 1    -0.019747  0.000205  0.000185  0.000166  0.000146  0.000126  0.000106
# 2     0.062851 -0.000178 -0.000115 -0.000052  0.000011  0.000074  0.000137
# 3    -0.210900 -0.000350 -0.000561 -0.000771 -0.000982 -0.001193 -0.001404
# 4     0.244845  0.000519  0.000764  0.001009  0.001254  0.001499  0.001744
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.275446 -0.000008  0.000268  0.000543  0.000819  0.001094  0.001370
# 9996 -0.041666 -0.000150 -0.000192 -0.000234 -0.000275 -0.000317 -0.000359
# 9997  0.045276  0.000228  0.000274  0.000319  0.000364  0.000410  0.000455
# 9998  0.036382 -0.000184 -0.000148 -0.000112 -0.000075 -0.000039 -0.000002
# 9999  0.183744  0.000481  0.000665  0.000849  0.001032  0.001216  0.001400
#
#             X6        X7
# 0     0.001739  0.001851
# 1     0.000087  0.000067
# 2     0.000200  0.000262
# 3    -0.001615 -0.001826
# 4     0.001988  0.002233
# ...        ...       ...
# 9995  0.001645  0.001920
# 9996 -0.000400 -0.000442
# 9997  0.000500  0.000545
# 9998  0.000034  0.000070
# 9999  0.001584  0.001767
#
# [10000 rows x 9 columns]

# %%
fig = plt.figure(figsize=(8, 4))
axs = np.zeros(2, dtype=object)
gs = fig.add_gridspec(1, 2)
axs[0] = fig.add_subplot(gs[0, 0:2])

k=0
for i in index_column[1:]:
    bins_n=abs(np.max(position_df[i])- np.min(position_df[i]))/0.00005
    axs[0].hist(position_df[i]*1000, bins=int(bins_n), facecolor = color[k+1], alpha=1,label = str(k)+' ms')
    k+=1

axs[0].legend()
# axs[0].set_title('Histogram of positioned population at different times',fontsize ='small')
axs[0].set_xlabel('Position (mm)')
axs[0].set_ylabel('Occurrence')
axs[0].grid()

# for x in axs.flat:
#     for tick in x.xaxis.get_major_ticks():
#         tick.label.set_fontsize('x-small')
#     for tick in x.yaxis.get_major_ticks():
#         tick.label.set_fontsize('x-small')
# fig.suptitle('A Monte Carlo simulation in one dimension (1D) of the position of a population')
fig.tight_layout()
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\1D atomic cloud simulation at 250 microkelvin.png')

# %%
fig = plt.figure(figsize=(8, 4))
axs = np.zeros(2, dtype=object)
gs = fig.add_gridspec(1, 2)
axs[0] = fig.add_subplot(gs[0, 0:2])


axs2 = axs[0].hist(position_df['V']*1000, bins=int(300), facecolor = 'darkred')
# axs[0].set_title('Histogram of velocity population at different times',fontsize ='small')
axs[0].set_xlabel('Velocity (mm/s)')
axs[0].set_ylabel('Occurrence')
axs[0].grid()

# for x in axs.flat:
#     for tick in x.xaxis.get_major_ticks():
#         tick.label.set_fontsize('x-small')
#     for tick in x.yaxis.get_major_ticks():
#         tick.label.set_fontsize('x-small')
# fig.suptitle('A Monte Carlo simulation in one dimension (1D) of the velocity of a population')
fig.tight_layout()
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\Velocity of 1D atomic cloud simulation at 250 microkelvin.png')

# %%
bins_l=[]
n_l=[]

for i in index_column[1:]:
    bins_n=abs(np.max(position_df[i])- np.min(position_df[i]))/0.00001
    n ,bins,p = plt.hist(position_df[i], bins=int(bins_n), facecolor = 'black')
    n_l.append(n)
    bins_l.append((bins[:-1]+bins[1:])/2)

# %%
Cloud_fit =[]
Cloud_std =[]
Cloud_std_err =[]
for i in range(8):
    Cloud_fit.append(gauss(bins_l[i], *gauss_fit(bins_l[i], n_l[i])))
    Cloud_std.append(gauss_fit(bins_l[i], n_l[i])[3])
    pcov_sigma = np.abs(gauss_fit_pcov(bins_l[i], n_l[i]))
    Cloud_std_err.append(np.sqrt(np.diag(pcov_sigma))[3])

# %%
ymax,ymin = 0.01,-0.0005
xmax,xmin = 6,-6
fig,(axs)=plt.subplots(2,4,figsize=(10,5))
k=0
for g in range(2):
    axs[g,0].set_ylabel('Probability')
    for p in range(4):
        axs[g,p].plot(bins_l[k]*1000,n_l[k]/sum(n_l[k]),'.',color = color[k],alpha = 0.2,label = 'Position of atoms')
        axs[g,p].plot(bins_l[k]*1000,Cloud_fit[k]/sum(n_l[k]),'-k',alpha = 1,label = 'Gaussian Fit')
        axs[g,p].set_title('$\Delta t$ = '+str(k)+' ms')
        axs[g,p].grid()
        axs[g,p].set_xlim(xmin,xmax)
        axs[g,p].set_ylim(ymin,np.max(n_l[0]/sum(n_l[0])))
        axs[g,p].legend(loc = 'upper left', fontsize = 'xx-small')
        axs[g,p].set_xlabel('Position (mm)')
        k+=1
# fig.suptitle('Monte Carlo simulation in one dimension (1D) of Rubidium atomic cloud')        
fig.tight_layout()
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\1D atomic cloud summation at 250 microkelvin.png')

# %%
time = np.arange(8)
plt.figure()
# plt.title('Least-square fitting')
plt.errorbar(time ,np.array(Cloud_std)*1000000, np.array(Cloud_std_err)*1000000 ,color = 'blue',fmt ='.',label = 'raw data',capsize=3, elinewidth=1, mfc = 'red')
# plt.errorbar(np.arange(1,7) ,sigma_exp*1000000, sigma_err_m*1000000,color = 'black',fmt ='o',label = 'Experiment data',capsize=3, elinewidth=1, mfc = 'orange')
plt.ylabel('Atomic radius ($\mu$m)')
plt.xlabel('$\Delta t$ (ms)')
plt.grid()
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\Ballistic expansion simulation at 250 microkelvin.png')

# %% [markdown]
# <h2>LSW<h2>

# %%
def lsq_weight(n,temp_range_min,temp_range_max,sigma_raw_array,sigma_raw_err):
    
    min_lsq = np.inf
    max_lsq = -np.inf
    lsq_list = []
    x_list = []
    y_list = []
    temp_range = np.linspace(temp_range_min,temp_range_max,n)
    n_of_time = len(sigma_raw_array)
    for i in range(n):
        sigma_sim = MOT_sim(ini_MOT_size,temp_range[i],n_of_time,sigma_raw_array)
        y_distance_weight = [((1/(sigma_raw_err[h]**2))*((sigma_raw_array[h]-sigma_sim[h])**2)) for h in range(n_of_time)]
        lsq = np.sum(y_distance_weight)
        std_of_mean = np.sqrt(lsq)/np.sqrt(n_of_time-1)
        
        if(lsq < min_lsq):
            min_lsq = lsq
            real_temp = temp_range[i]
            Percent_err = std_of_mean
        if(lsq > max_lsq):
            max_lsq = lsq
        lsq_list.append(lsq)
    coef = np.polyfit(temp_range,lsq_list,4)
    poly1d = np.poly1d(coef)
    min_n = np.where(poly1d(temp_range) == np.min(poly1d(temp_range)))
    temp_mean = temp_range[min_n][0]
    
    min_x = np.where(poly1d(temp_range) <= poly1d(temp_mean) + Percent_err**2)
    temp_min, temp_max = temp_range[np.min(min_x)], temp_range[np.max(min_x)]
    return lsq_list , temp_range, poly1d(temp_range), temp_min, temp_max, temp_mean, min_x, poly1d(temp_mean)+Percent_err**2

# %%
lsq_data_weight, temp_ranges_weight, lsq_fit_weight, MOT_temp_min, MOT_temp_max, MOT_temp_mean, temp_range_linear, err= lsq_weight(200,0e-6,210e-6,sigma_exp,sigma_err)

# %%
plt.figure()
plt.plot(temp_ranges_weight*1000000,lsq_data_weight,'.',label = 'Least square',alpha = 0.4, color ='blue')
plt.plot(temp_ranges_weight*1000000,lsq_fit_weight,'--',color = 'black',label = 'Polynomial degree 4 curve fitting')
plt.plot(temp_ranges_weight[temp_range_linear[0]]*1000000,err*np.ones(np.shape(temp_range_linear)[1]),color = 'black',label = 'Percentage error line')
plt.legend(loc = 'upper center',fontsize= 'x-small')
y_label = plt.ylabel(r'Least square ($m^2$)')
x_label = plt.xlabel('Temperatures ($\mu$k)')
plt.grid()
plt.title('Comparison of simulation and raw data \nusing weight least-square method')
plt.savefig('Comparison of simulation and raw data using weight least-square method')

# %%
Temp_array = np.array([MOT_temp_min, MOT_temp_mean, MOT_temp_max],dtype = float)
Cloud_gen, times, time = Multi_MOT_gen(ini_MOT_size,200,Temp_array,sigma_exp)
plt.figure()
plt.plot(time*1000,Cloud_gen[1],'--k',label = 'Temperature '+str(np.round(Temp_array[1]*1000000,2))+' $\mu$k')
plt.plot(time*1000,Cloud_gen[0],'--',color= 'orange',label = 'Temperature '+str(np.round(Temp_array[0]*1000000,2))+' $\mu$k')
plt.plot(time*1000,Cloud_gen[2],'--',color= 'green',label = 'Temperature '+str(np.round(Temp_array[2]*1000000,2))+' $\mu$k')
plt.errorbar(np.arange(1,7) ,sigma_exp, sigma_err,color = 'blue',fmt ='o',label = 'raw data',capsize=3, elinewidth=1, mfc = 'red')
y_label = plt.ylabel('Standard deviation (m)')
x_label = plt.xlabel('Time (ms)')
plt.grid()
plt.legend()

# %% [markdown]
# <h2>LS + errorbar<h2>

# %%
def lsq_normal(n,temp_range_min,temp_range_max,sigma_raw_array):
    
    min_lsq = np.inf
    max_lsq = -np.inf
    lsq_list = []
    x_list = []
    y_list = []
    temp_range = np.linspace(temp_range_min,temp_range_max,n)
    n_of_time = len(sigma_exp)
    
    for i in range(n):
        sigma_sim = MOT_sim(ini_MOT_size,temp_range[i],n_of_time,sigma_exp)
        y_distance = (sigma_exp-sigma_sim)
        lsq = np.sum(y_distance**2)
        
        if(lsq < min_lsq):
            min_lsq = lsq
            real_temp = temp_range[i]

        if(lsq > max_lsq):
            max_lsq = lsq
        lsq_list.append(lsq)
    coef = np.polyfit(temp_range,lsq_list,4)
    poly1d = np.poly1d(coef)
    min_n = np.where(poly1d(temp_range) == np.min(poly1d(temp_range)))
    temp_minimum = temp_range[min_n][0]
    
    return lsq_list,temp_minimum, temp_range, poly1d(temp_range)

# %%
lsq_data, nMOT_temp, temp_ranges, nlsq_fit = lsq_normal(200,0e-6,390e-6,sigma_exp)
sigma_max, sigma_min = sigma_exp + sigma_err, sigma_exp - sigma_err
lsq_max, nMOT_temp_max, temp_ranges_max, lsq_fit_max = lsq_normal(200,0e-6,390e-6,sigma_max)
lsq_min, nMOT_temp_min, temp_ranges_min, lsq_fit_min = lsq_normal(200,0e-6,390e-6,sigma_min)

# %%
colormap_fig2 = 'afmhot'
fig = plt.figure(figsize=(8, 4))
axs = np.zeros(2, dtype=object)
gs = fig.add_gridspec(1, 2)
axs[0] = fig.add_subplot(gs[0, 0])
axs[1] = fig.add_subplot(gs[0, 1])

axs1 = axs[0].plot(temp_ranges*1000000,lsq_min,'.b')
axs1 = axs[0].plot(temp_ranges*1000000,lsq_data,'.k')
axs1 = axs[0].plot(temp_ranges*1000000,lsq_max,'.r')
axs[0].set_title('Least square',fontsize ='small')
axs[0].set_xlabel('Temperature ($\mu$k)')
axs[0].set_ylabel(r'Least square ($m^2$)')
axs[0].grid()
axs2 = axs[1].plot(temp_ranges*1000000,lsq_fit_min,'--b')
axs2 = axs[1].plot(temp_ranges*1000000,nlsq_fit,'--k')
axs2 = axs[1].plot(temp_ranges*1000000,lsq_fit_max,'--r')
axs[1].set_title('Polynomial degree 4 curve fitting',fontsize ='small')
axs[1].set_xlabel('Temperature ($\mu$k)')
axs[1].grid()

for x in axs.flat:
    for tick in x.xaxis.get_major_ticks():
        tick.label.set_fontsize('x-small')
    for tick in x.yaxis.get_major_ticks():
        tick.label.set_fontsize('x-small')
fig.suptitle('Comparison of simulation and raw data \nusing least-square method')
fig.tight_layout()
plt.savefig('Full subtract signal method at 1ms.png')

# %%
nTemp_array = np.array([nMOT_temp_min, nMOT_temp, nMOT_temp_max],dtype = float)
nCloud_gen, times, time = Multi_MOT_gen(ini_MOT_size,200,nTemp_array,sigma_exp)
plt.figure()
plt.plot(time*1000,nCloud_gen[0],'--',color= 'orange',label = 'Temperature '+str(np.round(nTemp_array[0]*1000000,3))+' $\mu$k')
plt.plot(time*1000,nCloud_gen[1],'--k',label = 'Temperature '+str(np.round(nTemp_array[1]*1000000,3))+' $\mu$k')
plt.plot(time*1000,nCloud_gen[2],'--',color= 'orange',label = 'Temperature '+str(np.round(nTemp_array[2]*1000000,3))+' $\mu$k')
plt.errorbar(np.arange(1,7) ,sigma_exp, sigma_err,color = 'blue',fmt ='o',label = 'raw data',capsize=3, elinewidth=1, mfc = 'red')
y_label = plt.ylabel('Standard deviation (m)')
x_label = plt.xlabel('Time (ms)')
plt.grid()
plt.legend()

# %% [markdown]
# <h1>2D fitting<h1>

# %%
def lsq_2params(n,temp_range_min,temp_range_max,m,size_min,size_max,sigma_raw_array,sigma_raw_err):
    
    min_lsq = np.inf
    max_lsq = -np.inf
    n_of_time = len(sigma_raw_array)
    temp_range = np.linspace(temp_range_min,temp_range_max,n)
    size_range = np.linspace(size_min,size_max,m)
    twoD_lsq = []
    twoD_lsq_fit = []
    for j in range(m):
        x_list = []
        y_list = []    
        lsq_list = []
        scale_factor = size_range[j]/sigma_raw_array[0]
        sigma_array = scale_factor*sigma_raw_array
        sigma_array_err = scale_factor*sigma_raw_err
        for i in range(n):
            
            sigma_sim = MOT_sim(ini_MOT_size,temp_range[i],n_of_time,sigma_raw_array)
            y_distance_weight = [((1/(sigma_array_err[h]**2))*((sigma_array[h]-sigma_sim[h])**2)) for h in range(n_of_time)]
            lsq = np.sum(y_distance_weight)
            lsq_list.append(lsq)
        twoD_lsq.append(lsq_list)
        coef = np.polyfit(temp_range,lsq_list,4)
        poly1d = np.poly1d(coef)
        twoD_lsq_fit.append(poly1d(temp_range))
        
    return np.array(twoD_lsq), np.array(twoD_lsq_fit), temp_range*1000000, size_range*1000000

# %%
def lsq_err(lsq_array,lsq_fit_array,temp_data,size_data):
    min_point = np.where(lsq_fit_array == np.min(lsq_fit_array))
    size_lsq_array = lsq_array[:,min_point[1][0]]
    temp_lsq_array = lsq_array[min_point[0][0],:]
    
    L_temp_data = np.linspace(np.min(temp_data),np.max(temp_data),201)
    L_size_data = np.linspace(np.min(size_data),np.max(size_data),201)
    
    tcoef = np.polyfit(temp_data,temp_lsq_array,4)
    tpoly1d = np.poly1d(tcoef)
    temp_lsq_fit = tpoly1d(L_temp_data)
    scoef = np.polyfit(size_data,size_lsq_array,4)
    spoly1d = np.poly1d(scoef)
    size_lsq_fit = spoly1d(L_size_data)
    
    t_lsq_min = np.where(temp_lsq_fit == np.min(temp_lsq_fit))[0]
    s_lsq_min = np.where(size_lsq_fit == np.min(size_lsq_fit))[0]
    
    delta_a = 10
    at2 = L_temp_data[t_lsq_min]
    at1 = L_temp_data[t_lsq_min-delta_a]
    at3 = L_temp_data[t_lsq_min+delta_a]

    chit1 = np.min(temp_lsq_fit[t_lsq_min-delta_a])
    chit2 = np.min(temp_lsq_fit[t_lsq_min])
    chit3 = np.min(temp_lsq_fit[t_lsq_min+delta_a])
    atj = at3 - ((at3-at2)*(((chit3-chit2)/(chit1-(2*chit2)+chit3))+1/2))
    sigmatj = (at3-at2)*np.sqrt(2/(chit1-(2*chit2)+chit3))
    
    as2 = L_size_data[s_lsq_min]
    as1 = L_size_data[s_lsq_min-delta_a]
    as3 = L_size_data[s_lsq_min+delta_a]

    chis1 = np.min(size_lsq_fit[s_lsq_min-delta_a])
    chis2 = np.min(size_lsq_fit[s_lsq_min])
    chis3 = np.min(size_lsq_fit[s_lsq_min+delta_a])
    asj = as3 - ((as3-as2)*(((chis3-chis2)/(chis1-(2*chis2)+chis3))+1/2))
    sigmasj = (as3-as2)*np.sqrt(2/(chis1-(2*chis2)+chis3))
    
    temp_array_err = np.array([atj-sigmatj,atj,atj+sigmatj])
    size_array_err = np.array([asj-sigmasj,asj,asj+sigmasj])
    lsq_as = np.array([chis1,chis2,chis3])
    lsq_at = np.array([chit1,chit2,chit3])
    
    return temp_lsq_array, size_lsq_array,temp_array_err,size_array_err,lsq_as,lsq_at,temp_lsq_fit , size_lsq_fit

# %%
sigma_err = np.array([0.54697102 ,0.50053797 ,0.64864047 ,0.83312344 ,1.44395329 ,3.30220595 ])#,8.47620527 ,7.22363419 ,165.29643617 ,49.07438558]
sigma_exp_pixel = np.array([21.15636818, 20.8565363 , 22.63152476, 26.62544192, 29.5098059 ,37.5756262 ])
rubidium_mass=1.409993e-25
k=1.380649e-23
mu = 0
ini_MOT_size = 0.0005853782630731235

# %%
temp_min_fit,temp_max_fit,size_min_fit,size_max_fit = 0,400,0.5,0.9
lsq_data ,lsq_data_fit,temp_array,size_array = lsq_2params(51,temp_min_fit*1e-6,temp_max_fit*1e-6,51,size_min_fit*1e-3,size_max_fit*1e-3,sigma_exp_pixel,sigma_err)

# %%
scale_min = size_min_fit*1000/sigma_exp_pixel[0]
scale_max = size_max_fit*1000/sigma_exp_pixel[0]

# %%
levels = np.linspace(0,500,45)
plt.contourf(lsq_data_fit,300,cmap = 'Reds_r',levels = levels ,extent = (temp_min_fit,temp_max_fit,scale_min,scale_max))
plt.colorbar(label = '$\chi$')
plt.clim(5,500)
plt.xlabel('Temperature ($\mu$K)')
plt.ylabel('Scaling factor'+ r' ($\mu$m/pixel)')
# plt.title('2 parametric weighted Least-square fitting')
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\2 parametric weighted Least-square fitting.png')
# plt.legend()

# %%
temp_lsq_range,size_lsq_range,temp_err,size_err,size_lsq_err,temp_lsq_err,t_fit_lsq, s_fit_lsq = lsq_err(lsq_data ,lsq_data_fit,temp_array,size_array)
n=201
L_temp_array = np.linspace(np.min(temp_array),np.max(temp_array),n)
L_size_array = np.linspace(np.min(size_array),np.max(size_array),n)

# %%
colormap_fig2 = 'afmhot'
fig = plt.figure(figsize=(8, 4))
axs = np.zeros(2, dtype=object)
gs = fig.add_gridspec(1, 2)
axs[0] = fig.add_subplot(gs[0, 0])
axs[1] = fig.add_subplot(gs[0, 1])

axs1 = axs[0].plot(L_temp_array,t_fit_lsq,'-r', label = 'Polynomial degree 4 curve fitting')
axs1 = axs[0].plot(temp_array,temp_lsq_range,'.b',alpha = 0.4, label = 'Least square')
axs1 = axs[0].plot(temp_err,temp_lsq_err,'o',color = 'darkred')
axs1 = axs[0].fill_between(temp_err[:,0], -100, temp_lsq_err,alpha = 0.4,color = 'darkred',label = 'Temperature error')
axs[0].set_title('(a) Fixed Scaling factor ' + str(np.round(size_err[1][0]/sigma_exp_pixel[0],3))+r' ($\mu$m/pixel)',fontsize ='medium')
axs[0].set_xlabel('Temperature ($\mu$K)')
axs[0].set_ylabel('$\chi$')
axs[0].set_ylim(0,np.max(temp_lsq_range))
axs[0].legend(loc = 'upper center', fontsize = 'x-small')
axs[0].grid()

axs2 = axs[1].plot(L_size_array,s_fit_lsq,'-r', label = 'Polynomial degree 4 curve fitting')
axs2 = axs[1].plot(size_array,size_lsq_range,'.b',alpha = 0.4, label = 'Least square')
axs2 = axs[1].plot(size_err,size_lsq_err,'o',color = 'darkred')
axs2 = axs[1].fill_between(size_err[:,0], -100, size_lsq_err,alpha = 0.4,color = 'darkred',label = 'Size error')
axs[1].set_title('(b) Fixed temperature ' + str(np.round(temp_err[1][0],3)) +' $\mu$K',fontsize ='medium')
axs[1].set_xlabel('Scaling factor'+ r' ($\mu$m/pixel)')

axs[1].set_ylim(-20,np.max(size_lsq_range))
axs[1].legend(loc = 'upper center', fontsize = 'x-small')
axs[1].grid()

for x in axs.flat:
    for tick in x.xaxis.get_major_ticks():
        tick.label.set_fontsize('x-small')
    for tick in x.yaxis.get_major_ticks():
        tick.label.set_fontsize('x-small')
# fig.suptitle('Comparison of weighted Least-square method between Temperature and Scaling factor')
fig.tight_layout()
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\Comparison of weighted Least-square method.png')

# %%
scale_factor = (size_err[1]*1e-6)/sigma_exp_pixel[0]
sigma_exp = sigma_exp_pixel * scale_factor
sigma_err_m = sigma_err * scale_factor

Cloud_gen_fs_mean, times, time = Multi_MOT_gen(ini_MOT_size,n,temp_err*1e-6,sigma_exp)

# %%
plt.figure()
plt.fill_between(time*1000, Cloud_gen_fs_mean[0]*1000000, Cloud_gen_fs_mean[2]*1000000,alpha = 0.4,color = 'darkgray',label = 'Temperature '+str(np.int(temp_err[0][0]))+' to '+str(np.int(temp_err[2][0]))+' $\mu$K')
plt.plot(time*1000,Cloud_gen_fs_mean[1]*1000000,'--',color= 'black',label = 'Temperature '+str(np.int(temp_err[1][0]))+' $\mu$K')
plt.errorbar(np.arange(1,7) ,sigma_exp*1000000, sigma_err_m*1000000,color = 'blue',fmt ='o',label = 'Experiment data',capsize=3, elinewidth=1, mfc = 'red')
y_label = plt.ylabel('Atomic radius ($\mu$m)')
x_label = plt.xlabel('$\Delta t$ (ms)')
# plt.title('Ballistic expansion of rubidium cloud atoms \nat Scaling factor ' + str(np.round(size_err[1][0]//sigma_exp_pixel[0],3))+r' $(\frac{\mu m}{pixel})$')
plt.legend(loc = 'upper left', fontsize = 'small')
plt.grid()
plt.savefig('D:\\PICTURE\\Picture\\Pyplot\\2nd\\Ballistic expansion sim and ex.png')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2776\2415644558.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.fill_between(time*1000, Cloud_gen_fs_mean[0]*1000000, Cloud_gen_fs_mean[2]*1000000,alpha = 0.4,color = 'darkgray',label = 'Temperature '+str(np.int(temp_err[0][0]))+' to '+str(np.int(temp_err[2][0]))+' $\mu$K')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2776\2415644558.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.plot(time*1000,Cloud_gen_fs_mean[1]*1000000,'--',color= 'black',label = 'Temperature '+str(np.int(temp_err[1][0]))+' $\mu$K')
